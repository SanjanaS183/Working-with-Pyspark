# %% [markdown]
# #PartA

# %%
a_sorted = [["2015-08", 85609], ["2015-09", 173805], ["2015-10", 205045], ["2015-11", 234733], ["2015-12", 347092], 
            ["2016-01", 404816], ["2016-02", 520040], ["2016-03", 917170], ["2016-04", 1023096], ["2016-05", 1346796],
            ["2016-06", 1351536], ["2016-07", 1356907], ["2016-08", 1405743], ["2016-09", 1387412], ["2016-10", 1329847], 
            ["2016-11", 1301586], ["2016-12", 1316131], ["2017-01", 1409664], ["2017-02", 1410048], ["2017-03", 2426471], 
            ["2017-04", 2539966], ["2017-05", 4245516], ["2017-06", 7244657], ["2017-07", 7835875], ["2017-08", 10523178], 
            ["2017-09", 10679242], ["2017-10", 12602063], ["2017-11", 15292269], ["2017-12", 26732085], ["2018-01", 33504270], 
            ["2018-02", 22231978], ["2018-03", 20261862], ["2018-04", 20876642], ["2018-05", 25105717], ["2018-06", 22471788], 
            ["2018-07", 19937033], ["2018-08", 19842059], ["2018-09", 16056742], ["2018-10", 17056926], ["2018-11", 16713911], 
            ["2018-12", 17107601], ["2019-01", 1002431]]

# %%
months = [x[0] for x in a_sorted]
transactions = [x[1] for x in a_sorted]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 5))
xtick_labels = ['A \'15', 'S \'15', 'O \'15', 'N \'15', 'D \'15',
                'J \'16', 'F \'16', 'M \'16', 'A \'16', 'M \'16', 'J \'16',
                'J \'16', 'A \'16', 'S \'16', 'O \'16', 'N \'16', 'D \'16',
                'J \'17', 'F \'17', 'M \'17', 'A \'17', 'M \'17', 'J \'17', 'J \'17',
                'A \'17', 'S \'17', 'O \'17', 'N \'17', 'D \'17',
                'J \'18', 'F \'18', 'M \'18', 'A \'18', 'M \'18', 'J \'18', 'J \'18', 'A \'18',
                'S \'18', 'O \'18', 'N \'18', 'D \'18',
                'J \'19']
ax.bar(months, transactions)
ax.set_xlabel('Year-Month')
ax.set_ylabel('Number of Transactions')
ax.set_xticklabels(xtick_labels, rotation=45, ha='right')



plt.show()
# Out:
# <ipython-input-13-afabfb65e7dd>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xtick_labels, rotation=45, ha='right')

# %%
avg = [["2017-06", 1.1124614922552919e+18], ["2018-03", 1.494683174922994e+17], ["2017-05", 1.43325673913785e+18], 
              ["2018-06", 1.7065868174921306e+17], ["2018-02", 3.74545125035696e+17], ["2015-08", 1.1123582277086302e+17], 
              ["2018-10", 1.4161482962039715e+17], ["2016-02", 9.217354924562627e+16], ["2017-09", 9.925659999647519e+17], 
              ["2017-11", 1.225685368543751e+18], ["2017-03", 1.1614861315689065e+18], ["2017-02", 2.119170268195901e+17], 
              ["2016-11", 1.3952965197411798e+17], ["2018-07", 1.2264283520203792e+17], ["2018-12", 2.7500839302444915e+17], 
              ["2015-11", 3.7756563014209464e+16], ["2016-09", 1.2240620886056003e+17], ["2017-07", 1.376859729760914e+18], 
              ["2018-01", 1.0114745854375369e+18], ["2019-01", 1.1533079707812834e+16], ["2017-01", 2.1423317784431776e+17], 
              ["2016-03", 1.1371844483859166e+17], ["2016-10", 1.166687341771106e+17], ["2015-10", 4.112313145790391e+16], 
              ["2015-09", 3.311665433816921e+16], ["2016-12", 2.187514419462952e+17], ["2017-12", 9.925554516033732e+17], 
              ["2018-08", 1.287125177998001e+17], ["2016-05", 1.713337250143759e+17], ["2018-09", 1.621004031303718e+17], 
              ["2016-06", 1.114301000493259e+17], ["2017-08", 1.3736387063046833e+18], ["2016-04", 6.2718075458243704e+16], 
              ["2017-10", 9.119374562262726e+17], ["2017-04", 7.647704941883992e+17], ["2016-01", 6.684521927252639e+16], 
              ["2016-07", 3.5142254643097395e+17], ["2015-12", 2.511943658598164e+16], ["2018-05", 1.69594186788139e+17], 
              ["2018-04", 1.3826418634730352e+17], ["2018-11", 2.4395872578117078e+17], ["2016-08", 2.245813734236469e+17]]

# %%
avg_sorted = sorted(avg, key = lambda x: x[0])

# %%
months = [x[0] for x in avg_sorted]
avg_value_tr = [x[1] for x in avg_sorted]

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(months, avg_value_tr)
ax.set_xlabel('Year-Month')
ax.set_ylabel('Avg value of Transactions')
ax.set_xticklabels(xtick_labels, rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-18-b823d621a0f5>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xtick_labels, rotation=45, ha='right')
